# %%
#@title Texto de título predeterminado
import matplotlib.pyplot as plt
import math
def biseccion():
    print("Metodo de la biseccion")
    print("Suponiendo nuestra funcion sea 5x al cubo - 5x al cuadrado + 6x -2 ")
    print("Siendo los intervalos [0,1]")
    xl=0
    xu=1
    fxl=((5*(xl**3))-(5*(xl**2))+(6*xl)-2)
    fxu=((5*(xu**3))-(5*(xu**2))+(6*xu)-2)
    xrgrafico=[]
    xlgrafico=[]
    xugrafico=[]
    xlgrafico.append(xl)
    xugrafico.append(xu)
    if (fxu*fxl<0):
        xr=(xl+xu)/2
        fxr =((5*(xr**3))-(5*(xr**2))+(6*xr)-2)
        xrgrafico.append(xr)
        xlgrafico.append(xl)
        xugrafico.append(xu)
        c=0
        print("El valor de xr es "+ str(xr))
        er = 1
        while er > (10**-5):
            if(fxu*fxr<0):
                xl=xr
                fxl =((5*(xl**3))-(5*(xl**2))+(6*xl)-2)
                fxu =((5*(xu**3))-(5*(xu**2))+(6*xu)-2)
                xr = (xl + xu) / 2
                fxr =((5*(xr**3))-(5*(xr**2))+(6*xr)-2)
                er=(xr-xl)/xr
                xrgrafico.append(xr)
                xlgrafico.append(xl)
                xugrafico.append(xu)
                print("El valor de xr es "+ str(xr))
            if (fxl * fxr < 0):
                xu=xr
                fxl =((5*(xl**3))-(5*(xl**2))+(6*xl)-2)
                fxu =((5*(xu**3))-(5*(xu**2))+(6*xu)-2)
                xr = (xl + xu) / 2
                fxr =((5*(xr**3))-(5*(xr**2))+(6*xr)-2)
                er = (xr - xl) / xr
                xrgrafico.append(xr)
                xlgrafico.append(xl)
                xugrafico.append(xu)
                print("El valor de xr es "+ str(xr))
            if (fxu*fxr>0 and fxl*fxr>0):
                print("No tiene raiz, fin del programa")
        plt.plot(xrgrafico)
        plt.plot(xlgrafico)
        plt.plot(xugrafico)
        plt.show
    else:
        print("No tiene raiz, fin del programa")
biseccion()
# Out:
# Metodo de la biseccion
# Suponiendo nuestra funcion sea 5x al cubo - 5x al cuadrado + 6x -2
# Siendo los intervalos [0,1]
# El valor de xr es 0.5
# El valor de xr es 0.25
# El valor de xr es 0.375
# El valor de xr es 0.4375
# El valor de xr es 0.40625
# El valor de xr es 0.421875
# El valor de xr es 0.4140625
# El valor de xr es 0.41796875
# El valor de xr es 0.419921875
# El valor de xr es 0.4189453125
# El valor de xr es 0.41845703125
# El valor de xr es 0.418212890625
# El valor de xr es 0.4180908203125
# El valor de xr es 0.41815185546875
# El valor de xr es 0.418121337890625
# El valor de xr es 0.4181060791015625
# El valor de xr es 0.41809844970703125
# El valor de xr es 0.4181022644042969
# El valor de xr es 0.41810035705566406
